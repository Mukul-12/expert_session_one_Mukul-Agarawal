# %% [markdown]
# # Data Preparation
#
# In this notebook we preapare data for our search function.
# In this we have one csv file.
# * bloodtypes.csv

# %%
# Import the needed  modules...
import pandas as pd
import numpy as np

# %% [markdown]
# # Define Path to Data File

# %%
# we get the path at which our file bloodtypes.csv is stored.
from os import getcwd
path = f"{getcwd()}/Data Store/bloodtypes2.csv"

# %%
path
# Out:
# 'C:\\Users\\Mukul Agarawal\\Desktop\\JOVAC/Data Store/bloodtypes2.csv'

# %% [markdown]
# # Data Engineering
#
# * Get data in the dataframes

# %%
# Read data from bloodtypes.csv

blood_group = pd.read_csv(path)

# %%
# Display bloodgroup.csv file data

blood_group
# Out:
#     Unnamed: 0        Country      Population      O+      A+      B+    AB+  \
# 0            0      Argentina     4,42,70,440  45.40%  34.26%   8.59%  2.64%
# 1            1        Armenia       29,31,568  29.00%  46.30%  12.00%  5.60%
# 2            2      Australia     2,46,42,693  40.00%  31.00%   8.00%  2.00%
# 3            3        Austria       85,92,470  30.00%  33.00%  12.00%  6.00%
# 4            4     Bangladesh    16,48,33,667  31.18%  21.44%  34.58%  8.85%
# ..         ...            ...             ...     ...     ...     ...    ...
# 75          75  Unitedkingdom     4,44,04,078  32.00%  34.00%  15.00%  5.00%
# 76          76      Venezuela     3,20,11,082  58.50%  28.30%   5.30%  1.80%
# 77          77        Vietnam     9,54,14,640  41.70%  21.90%  30.80%  4.98%
# 78          78       Zimbabwe     1,66,42,880  63.30%  18.50%  14.60%  0.99%
# 79          79          Mundo  6,63,52,81,257  38.67%  27.42%  22.02%  5.88%
#
#        O-     A-     B-    AB-
# ...

# %%
# Here I drop the Unnamed column in our blood_group data frame

blood_group = blood_group.drop(['Unnamed: 0'],axis=1)
blood_group.head(15)
# Out:
#        Country      Population      O+      A+      B+    AB+     O-     A-  \
# 0    Argentina     4,42,70,440  45.40%  34.26%   8.59%  2.64%  8.40%  0.44%
# 1      Armenia       29,31,568  29.00%  46.30%  12.00%  5.60%  2.00%  3.70%
# 2    Australia     2,46,42,693  40.00%  31.00%   8.00%  2.00%  9.00%  7.00%
# 3      Austria       85,92,470  30.00%  33.00%  12.00%  6.00%  7.00%  8.00%
# 4   Bangladesh    16,48,33,667  31.18%  21.44%  34.58%  8.85%  1.39%  0.96%
# 5      Bolivia     1,10,53,376  51.53%  29.45%  10.11%  1.15%  4.39%  2.73%
# 6       Brazil    21,12,48,418  36.00%  34.00%   8.00%  2.50%  9.00%  8.00%
# 7     Bulgaria       70,45,097  28.00%  37.00%  13.00%  7.00%  5.00%  7.00%
# 8      Camboja     1,60,77,172  46.70%  27.20%  18.50%  4.90%  1.30%  0.80%
# 9       Canada     3,66,27,140  39.00%  36.00%   7.60%  2.50%  7.00%  6.00%
# 10       Chile     1,83,14,060  85.50%   8.70%   3.35%  1.00%  1.20%  0.10%
# ...

# %%
# Make country as an index column having discrete country name.

blood_group.set_index('Country', inplace=True)
blood_group
# Out:
#                    Population      O+      A+      B+    AB+     O-     A-  \
# Country
# Argentina         4,42,70,440  45.40%  34.26%   8.59%  2.64%  8.40%  0.44%
# Armenia             29,31,568  29.00%  46.30%  12.00%  5.60%  2.00%  3.70%
# Australia         2,46,42,693  40.00%  31.00%   8.00%  2.00%  9.00%  7.00%
# Austria             85,92,470  30.00%  33.00%  12.00%  6.00%  7.00%  8.00%
# Bangladesh       16,48,33,667  31.18%  21.44%  34.58%  8.85%  1.39%  0.96%
# ...                       ...     ...     ...     ...    ...    ...    ...
# Unitedkingdom     4,44,04,078  32.00%  34.00%  15.00%  5.00%  5.00%  6.00%
# Venezuela         3,20,11,082  58.50%  28.30%   5.30%  1.80%  3.50%  1.70%
# Vietnam           9,54,14,640  41.70%  21.90%  30.80%  4.98%  0.30%  0.10%
# Zimbabwe          1,66,42,880  63.30%  18.50%  14.60%  0.99%  1.70%  0.50%
# Mundo          6,63,52,81,257  38.67%  27.42%  22.02%  5.88%  2.55%  1.99%
#
#                   B-    AB-
# Country
# ...

# %%
# In this way we get complete infornmation of any country. 

blood_group.loc['Argentina']
# Out:
# Population    4,42,70,440
# O+                 45.40%
# A+                 34.26%
# B+                  8.59%
# AB+                 2.64%
# O-                  8.40%
# A-                  0.44%
# B-                  0.21%
# AB-                 0.06%
# Name: Argentina, dtype: object

# %%
# Index of series having column name

blood_group.keys()
# Out:
# Index(['Population', 'O+', 'A+', 'B+', 'AB+', 'O-', 'A-', 'B-', 'AB-'], dtype='object')

# %%
# It provide the information how many column are filled without not null value and display its data type.

blood_group.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80 entries, Argentina to Mundo
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Population  80 non-null     object
#  1   O+          80 non-null     object
#  2   A+          80 non-null     object
#  3   B+          80 non-null     object
#  4   AB+         80 non-null     object
#  5   O-          80 non-null     object
#  6   A-          80 non-null     object
#  7   B-          80 non-null     object
#  8   AB-         80 non-null     object
# dtypes: object(9)
# memory usage: 8.3+ KB
